# %% [markdown]
# ## Set Up Environment and Import Data

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from scipy import stats

sns.set_theme()

# %%
FILENAME='Case Study Data - Comp Research Associate(1)'
SHEET1 = 'recruiting_activity'
SHEET2 = 'candidate_profile'

# %%
# Import datasets separately
df_rec = pd.read_excel("{}.xlsx".format(FILENAME), sheet_name=SHEET1)
df_prof = pd.read_excel("{}.xlsx".format(FILENAME), sheet_name=SHEET2)

# %% [markdown]
# ## Profiling

# %%
# Get dimensions of datasets
print(df_rec.shape)
print(df_prof.shape)
# Out:
# (4996, 6)
# (4959, 10)

# %%
# This confirms that we have duplicate candidate id in the df_rec dataframe
df_rec.cand_id.unique().shape
# Out:
# (4959,)

# %%
# This confirms that we do not have duplicate candidate id in the df_prof dataframe
df_prof.cand_id.unique().shape
# Out:
# (4959,)

# %%
# This confirms that there is a perfect inetersect of employees from one dataset to the other
print([x for x in df_rec.cand_id.unique() if x not in df_prof.cand_id.unique()])
print([x for x in df_prof.cand_id.unique() if x not in df_rec.cand_id.unique()])
# Out:
# []
# []

# %%
df = df_rec.merge(df_prof, on='cand_id', how='left')
df.head()
# Out:
#    cand_id     position     dept      furthest_stage             app_date  \
# 0  4188467  UX Designer  Product     New Application  2018-02-03 00:00:00
# 1   433034  UX Designer  Product  In-House Interview  2018-12-20 00:00:00
# 2   337226  UX Designer  Product  In-House Interview  2017-02-27 00:00:00
# 3  6108441  UX Designer  Product        Phone Screen  2017-06-15 00:00:00
# 4  1536927  UX Designer  Product  In-House Interview  2017-10-18 00:00:00
#
#       app_source  comp_exp    yrs_exp    industry   degree_1 school_region_1  \
# 0         Agency     75000  14.000000  Technology  Bachelors        region_5
# 1        Website     74900  13.951020       Other  Bachelors        region_4
# 2         Agency     73400  13.216327       Other  Bachelors        region_4
# 3         Agency     72200  12.628571  Technology  Bachelors        region_5
# 4  Advertisement     71900  12.481633  Technology  Bachelors        region_4
#
#   degree_2 school_region_2 degree_3 school_region_3
# 0  Masters        region_5      NaN             NaN
# 1  Masters        region_1      NaN             NaN
# 2  Masters        region_4      NaN             NaN
# 3      NaN             NaN      NaN             NaN
# 4  Masters        region_4      NaN             NaN

# %%
df.describe()
# Out:
#             cand_id       comp_exp      yrs_exp
# count  4.996000e+03    4996.000000  4996.000000
# mean   2.450057e+06   72015.632506    17.816077
# std    2.303560e+06   11504.386499     9.579444
# min    2.468000e+03    1500.000000     0.000000
# 25%    2.398512e+05   64400.000000     9.044776
# 50%    1.662334e+06   70900.000000    14.820896
# 75%    4.605206e+06   79200.000000    27.614754
# max    6.377786e+06  450000.000000    36.262295

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4996 entries, 0 to 4995
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cand_id          4996 non-null   int64
#  1   position         4996 non-null   object
#  2   dept             4996 non-null   object
#  3   furthest_stage   4996 non-null   object
#  4   app_date         4996 non-null   object
#  5   app_source       4996 non-null   object
#  6   comp_exp         4996 non-null   int64
#  7   yrs_exp          4996 non-null   float64
#  8   industry         4996 non-null   object
#  9   degree_1         4996 non-null   object
#  10  school_region_1  4996 non-null   object
#  11  degree_2         2142 non-null   object
#  12  school_region_2  2142 non-null   object
#  13  degree_3         914 non-null    object
#  14  school_region_3  914 non-null    object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 624.5+ KB

# %%
df.isna().sum()
# Out:
# cand_id               0
# position              0
# dept                  0
# furthest_stage        0
# app_date              0
# app_source            0
# comp_exp              0
# yrs_exp               0
# industry              0
# degree_1              0
# school_region_1       0
# degree_2           2854
# school_region_2    2854
# degree_3           4082
# school_region_3    4082
# dtype: int64

# %%
df.groupby(['industry','dept','position']).size()
# Out:
# industry    dept         position
# Finance     Engineering  Associate Software Developer      542
#                          Sr. Software Engineer              10
#             Finance      Business Operations Manager        34
#                          Finance Generalist                 30
#                          Finance Manager                    30
#                          Financial Analyst                   9
#             IT           IT Analyst                         16
#                          Sr. Business Analyst               31
#             Product      Associate Product Manager         151
#                          Sr. Product Manager                17
#                          UX Designer                        11
#             Sales        Account Executive                  36
#                          Associate Relationship Manager    345
# Government  Engineering  Associate Software Developer      500
#                          Sr. Software Engineer               9
#             Finance      Business Operations Manager        43
#                          Finance Generalist                 37
#                          Finance Manager                    50
#                          Financial Analyst                   6
#             IT           IT Analyst                         16
#                          Sr. Business Analyst               24
#             Product      Associate Product Manager         143
#                          Sr. Product Manager                11
#                          UX Designer                        15
#             Sales        Account Executive                  37
#                          Associate Relationship Manager    344
# Other       Engineering  Associate Software Developer      515
#                          Sr. Software Engineer              10
#             Finance      Business Operations Manager        52
#                          Finance Generalist                 31
#                          Finance Manager                    44
#                          Financial Analyst                  10
#             IT           IT Analyst                         19
#                          Sr. Business Analyst               20
#             Product      Associate Product Manager         129
#                          Sr. Product Manager                31
#                          UX Designer                        18
#             Sales        Account Executive                  38
#                          Associate Relationship Manager    334
# Technology  Engineering  Associate Software Developer      534
#                          Sr. Software Engineer               4
#             Finance      Business Operations Manager        34
#                          Finance Generalist                 30
#                          Finance Manager                    46
#                          Financial Analyst                  11
#             IT           IT Analyst                         11
#                          Sr. Business Analyst               22
#             Product      Associate Product Manager         159
#                          Sr. Product Manager                16
#                          UX Designer                        10
#             Sales        Account Executive                  36
#                          Associate Relationship Manager    335
# dtype: int64

# %%
# Use for markdown
print(df.head().to_markdown())
# Out:
# |      |   cand_id | position                       | dept        | furthest_stage   | app_date            | app_source       |   comp_exp |   yrs_exp | industry   | degree_1   | school_region_1   | degree_2   | school_region_2   | degree_3   | school_region_3   | Highest Degree   |
# |-----:|----------:|:-------------------------------|:------------|:-----------------|:--------------------|:-----------------|-----------:|----------:|:-----------|:-----------|:------------------|:-----------|:------------------|:-----------|:------------------|:-----------------|
# |  820 |      2468 | Associate Software Developer   | Engineering | Offer Sent       | 2018-11-01 00:00:00 | Campus Job Board |      85100 |  36.2623  | Government | PhD        | region_5          | Masters    | region_4          | Bachelors  | region_2          | PhD              |
# | 4002 |      2471 | Associate Relationship Manager | Sales       | Offer Sent       | 2018-12-13 00:00:00 | Campus Event     |      74700 |   8.37313 | Other      | Masters    | region_2          | Bachelors  | region_5          | nan        | nan               | Masters          |
# | 1181 |      2475 | Associate Software Developer   | Engineering | Offer Sent       | 2018-12-21 00:00:00 | Advertisement    |      70900 |  30.4426  | Government | Masters    | region_5          | Bachelors  | region_3          | nan        | nan               | Masters          |
# | 2917 |      2480 | Associate Relationship Manager | Sales       | Offer Sent       | 2018-12-25 00:00:00 | Campus Event     |      93000 |  16.5672  | Government | Masters    | region_2          | Bachelors  | region_3          | nan        | nan               | Masters          |
# | 3290 |      2486 | Associate Relationship Manager | Sales       | Offer Sent       | 2018-12-06 00:00:00 | Campus Event     |      82500 |  11.8657  | Other      | Masters    | region_1          | Bachelors  | region_5          | nan        | nan               | Masters          |

# %% [markdown]
# ## Adding Highest Degree

# %%
df['Degree Concat'] = df.degree_1.astype(str)+df.degree_2.astype(str)+df.degree_3.astype(str)

df['Highest Degree'] = np.where(df['Degree Concat'].str.contains('PhD'), "PhD",
                                np.where(df['Degree Concat'].str.contains('JD'), "JD", 
                                         np.where(df['Degree Concat'].str.contains('Masters'), "Masters", 
                                                  np.where(df['Degree Concat'].str.contains('Bachelors'), "Bachelors", "")
                                                  )
                                         )
                                )

df = df.drop(['Degree Concat'], axis=1)

# %%
df['Highest Degree'] .value_counts()
# Out:
# Bachelors    2854
# Masters      1228
# PhD           914
# Name: Highest Degree, dtype: int64

# %% [markdown]
# ## Deduplications

# %%
# Creating a numerical hierarchy for the stages reached
# Ordering candidates based on this hierarchy so that duplication retains only the application with the latest stage
df['furthers_stage_enc'] = df["furthest_stage"].replace({
    'New Application':1,
    'Phone Screen':2,
    'In-House Interview':3,
    'Offer Sent':4
})
df = df.sort_values(['cand_id', 'dept', 'furthest_stage']).drop_duplicates(['cand_id', 'dept'], keep='last')
df = df.drop(['furthers_stage_enc'], axis=1)

# %% [markdown]
# ## Funnel

# %%
# Creating funnel by pivoting our data accordingly
funnel = df.pivot_table(values='cand_id', index=['furthest_stage'], columns='Highest Degree', aggfunc='count')
funnel = funnel.reindex(['New Application', 'Phone Screen','In-House Interview',  'Offer Sent'])
funnel['Bachelors Conversion Rate'] = funnel['Bachelors'].transform(lambda x: x / x.shift(1))

funnel['Masters Conversion Rate'] = funnel['Masters'].transform(lambda x: x / x.shift(1))
funnel['PhD Conversion Rate'] = funnel['PhD'].transform(lambda x: x /x.shift(1))

funnel = funnel.rename({'Bachelors':'Bachelors Applicants',
               'Masters':'Masters Applicants',
               'PhD':'PhD Applicants'}, axis=1)

funnel = funnel.reindex(sorted(funnel.columns), axis=1)
funnel = funnel.fillna(0)

funnel.style.format({
    'Bachelors Conversion Rate': '{:,.0%}'.format,
    'Masters Conversion Rate': '{:,.0%}'.format,
    'PhD Conversion Rate': '{:,.0%}'.format,
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_b1ebc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Highest Degree</th>
#       <th id="T_b1ebc_level0_col0" class="col_heading level0 col0" >Bachelors Applicants</th>
#       <th id="T_b1ebc_level0_col1" class="col_heading level0 col1" >Bachelors Conversion Rate</th>
#       <th id="T_b1ebc_level0_col2" class="col_heading level0 col2" >Masters Applicants</th>
#       <th id="T_b1ebc_level0_col3" class="col_heading level0 col3" >Masters Conversion Rate</th>
#       <th id="T_b1ebc_level0_col4" class="col_heading level0 col4" >PhD Applicants</th>
#       <th id="T_b1ebc_level0_col5" class="col_heading level0 col5" >PhD Conversion Rate</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >furthest_stage</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1ebc_level0_row0" class="row_heading level0 row0" >New Application</th>
#       <td id="T_b1ebc_row0_col0" class="data row0 col0" >2182</td>
#       <td id="T_b1ebc_row0_col1" class="data row0 col1" >0%</td>
#       <td id="T_b1ebc_row0_col2" class="data row0 col2" >842</td>
#       <td id="T_b1ebc_row0_col3" class="data row0 col3" >0%</td>
#       <td id="T_b1ebc_row0_col4" class="data row0 col4" >354</td>
#       <td id="T_b1ebc_row0_col5" class="data row0 col5" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_b1ebc_level0_row1" class="row_heading level0 row1" >Phone Screen</th>
#       <td id="T_b1ebc_row1_col0" class="data row1 col0" >342</td>
#       <td id="T_b1ebc_row1_col1" class="data row1 col1" >16%</td>
#       <td id="T_b1ebc_row1_col2" class="data row1 col2" >174</td>
#       <td id="T_b1ebc_row1_col3" class="data row1 col3" >21%</td>
#       <td id="T_b1ebc_row1_col4" class="data row1 col4" >264</td>
#       <td id="T_b1ebc_row1_col5" class="data row1 col5" >75%</td>
#     </tr>
#     <tr>
#       <th id="T_b1ebc_level0_row2" class="row_heading level0 row2" >In-House Interview</th>
#       <td id="T_b1ebc_row2_col0" class="data row2 col0" >250</td>
#       <td id="T_b1ebc_row2_col1" class="data row2 col1" >73%</td>
#       <td id="T_b1ebc_row2_col2" class="data row2 col2" >172</td>
#       <td id="T_b1ebc_row2_col3" class="data row2 col3" >99%</td>
#       <td id="T_b1ebc_row2_col4" class="data row2 col4" >262</td>
#       <td id="T_b1ebc_row2_col5" class="data row2 col5" >99%</td>
#     </tr>
#     <tr>
#       <th id="T_b1ebc_level0_row3" class="row_heading level0 row3" >Offer Sent</th>
#       <td id="T_b1ebc_row3_col0" class="data row3 col0" >64</td>
#       <td id="T_b1ebc_row3_col1" class="data row3 col1" >26%</td>
#       <td id="T_b1ebc_row3_col2" class="data row3 col2" >30</td>
#       <td id="T_b1ebc_row3_col3" class="data row3 col3" >17%</td>
#       <td id="T_b1ebc_row3_col4" class="data row3 col4" >30</td>
#       <td id="T_b1ebc_row3_col5" class="data row3 col5" >11%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Use for markdown
print(funnel.to_markdown())
# Out:
# | furthest_stage     |   Bachelors Applicants |   Bachelors Conversion Rate |   Masters Applicants |   Masters Conversion Rate |   PhD Applicants |   PhD Conversion Rate |
# |:-------------------|-----------------------:|----------------------------:|---------------------:|--------------------------:|-----------------:|----------------------:|
# | New Application    |                   2182 |                    0        |                  842 |                  0        |              354 |              0        |
# | Phone Screen       |                    342 |                    0.156737 |                  174 |                  0.206651 |              264 |              0.745763 |
# | In-House Interview |                    250 |                    0.730994 |                  172 |                  0.988506 |              262 |              0.992424 |
# | Offer Sent         |                     64 |                    0.256    |                   30 |                  0.174419 |               30 |              0.114504 |

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Overall Regression

# %%
# Run regression for overall data using only subset of columns
cols = [
    # 'position', 
        'dept',  'furthest_stage', 'app_source', 'comp_exp', 'yrs_exp', 'industry','Highest Degree']

X = pd.get_dummies(df[cols], drop_first='True').drop(['comp_exp'], axis=1)
y = np.log(df.comp_exp)

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               comp_exp   R-squared:                       0.743
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     713.4
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):               0.00
# Time:                        20:00:12   Log-Likelihood:                 5740.6
# No. Observations:                4966   AIC:                        -1.144e+04
# Df Residuals:                    4945   BIC:                        -1.130e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             10.3581      0.011    950.260      0.000      10.337      10.379
# yrs_exp                            0.0256      0.000     74.421      0.000       0.025       0.026
# dept_Finance                       0.5256      0.007     76.319      0.000       0.512       0.539
# dept_IT                            0.4765      0.009     55.540      0.000       0.460       0.493
# dept_Product                       0.5704      0.008     74.001      0.000       0.555       0.586
# dept_Sales                         0.6530      0.007     97.057      0.000       0.640       0.666
# furthest_stage_New Application     0.0068      0.003      2.017      0.044       0.000       0.013
# furthest_stage_Offer Sent         -0.0014      0.007     -0.188      0.851      -0.016       0.013
# furthest_stage_Phone Screen       -0.0017      0.004     -0.434      0.664      -0.010       0.006
# app_source_Agency                  0.0735      0.006     11.875      0.000       0.061       0.086
# app_source_Campus Event           -0.0034      0.005     -0.719      0.472      -0.013       0.006
# app_source_Campus Job Board       -0.0009      0.004     -0.225      0.822      -0.009       0.007
# app_source_Career Fair            -0.0021      0.004     -0.505      0.614      -0.010       0.006
# app_source_Internal Referral       0.0519      0.012      4.255      0.000       0.028       0.076
# app_source_Outsourced             -0.0472      0.010     -4.955      0.000      -0.066      -0.029
# app_source_Website                 0.0222      0.005      4.779      0.000       0.013       0.031
# industry_Government               -0.0002      0.003     -0.079      0.937      -0.006       0.006
# industry_Other                    -0.0012      0.003     -0.404      0.686      -0.007       0.005
# industry_Technology               -0.0034      0.003     -1.109      0.267      -0.009       0.003
# Highest Degree_Masters            -0.0015      0.003     -0.557      0.577      -0.007       0.004
# Highest Degree_PhD                 0.0331      0.003      9.947      0.000       0.027       0.040
# ==============================================================================
# Omnibus:                     7422.224   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         91962257.454
# Skew:                          -7.831   Prob(JB):                         0.00
# Kurtosis:                     669.480   Cond. No.                         316.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
def format_coef(est):
    df = pd.DataFrame.from_records(est.summary().tables[1].data)
    header  = df.iloc[0] # grab the first row for the header
    df = df[1:] # take the data less the header row
    df.columns = header 
    df['Exp. Coef.'] = np.exp(df['coef'].astype(float))-1
    return df

# %%
coef_ovr = format_coef(est2)
coef_ovr
# Out:
# 0                                         coef    std err          t   P>|t|  \
# 1                            const     10.3581      0.011    950.260   0.000
# 2                          yrs_exp      0.0256      0.000     74.421   0.000
# 3                     dept_Finance      0.5256      0.007     76.319   0.000
# 4                          dept_IT      0.4765      0.009     55.540   0.000
# 5                     dept_Product      0.5704      0.008     74.001   0.000
# 6                       dept_Sales      0.6530      0.007     97.057   0.000
# 7   furthest_stage_New Application      0.0068      0.003      2.017   0.044
# 8        furthest_stage_Offer Sent     -0.0014      0.007     -0.188   0.851
# 9      furthest_stage_Phone Screen     -0.0017      0.004     -0.434   0.664
# 10               app_source_Agency      0.0735      0.006     11.875   0.000
# 11         app_source_Campus Event     -0.0034      0.005     -0.719   0.472
# 12     app_source_Campus Job Board     -0.0009      0.004     -0.225   0.822
# 13          app_source_Career Fair     -0.0021      0.004     -0.505   0.614
# 14    app_source_Internal Referral      0.0519      0.012      4.255   0.000
# 15           app_source_Outsourced     -0.0472      0.010     -4.955   0.000
# 16              app_source_Website      0.0222      0.005      4.779   0.000
# 17             industry_Government     -0.0002      0.003     -0.079   0.937
# 18                  industry_Other     -0.0012      0.003     -0.404   0.686
# 19             industry_Technology     -0.0034      0.003     -1.109   0.267
# 20          Highest Degree_Masters     -0.0015      0.003     -0.557   0.577
# 21              Highest Degree_PhD      0.0331      0.003      9.947   0.000
#
# 0      [0.025     0.975]    Exp. Coef.
# 1      10.337     10.379  31510.253028
# 2       0.025      0.026      0.025930
# 3       0.512      0.539      0.691473
# 4       0.460      0.493      0.610428
# 5       0.555      0.586      0.768974
# 6       0.640      0.666      0.921296
# 7       0.000      0.013      0.006823
# 8      -0.016      0.013     -0.001399
# 9      -0.010      0.006     -0.001699
# 10      0.061      0.086      0.076269
# 11     -0.013      0.006     -0.003394
# 12     -0.009      0.007     -0.000900
# 13     -0.010      0.006     -0.002098
# 14      0.028      0.076      0.053270
# 15     -0.066     -0.029     -0.046103
# 16      0.013      0.031      0.022448
# 17     -0.006      0.006     -0.000200
# 18     -0.007      0.005     -0.001199
# 19     -0.009      0.003     -0.003394
# 20     -0.007      0.004     -0.001499
# 21      0.027      0.040      0.033654

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)  for i in range(len(X.columns))]

vif_data
# Out:
#                            feature       VIF
# 0                          yrs_exp  9.630225
# 1                     dept_Finance  2.198069
# 2                          dept_IT  1.243027
# 3                     dept_Product  2.233854
# 4                       dept_Sales  3.243485
# 5   furthest_stage_New Application  5.909276
# 6        furthest_stage_Offer Sent  1.176481
# 7      furthest_stage_Phone Screen  2.069994
# 8                app_source_Agency  1.770793
# 9          app_source_Campus Event  2.250839
# 10     app_source_Campus Job Board  4.220470
# 11          app_source_Career Fair  2.905963
# 12    app_source_Internal Referral  1.150545
# 13           app_source_Outsourced  1.511974
# 14              app_source_Website  2.200327
# 15             industry_Government  1.938038
# 16                  industry_Other  1.950244
# 17             industry_Technology  1.959360
# 18          Highest Degree_Masters  1.559713
# 19              Highest Degree_PhD  1.728698

# %% [markdown]
# ### Regression by Department

# %%
def regress(df):
    cols2 = [ 'position', 'furthest_stage', 'app_source', 'comp_exp', 'yrs_exp', 'industry','Highest Degree']

    X = pd.get_dummies(df[cols2], drop_first='True').drop(['comp_exp'], axis=1)
    y = np.log(df.comp_exp)

    X2 = sm.add_constant(X)
    est = sm.OLS(y, X2)
    est = est.fit()
    return est

# %%
regression_tracker = {}
for dept in df.dept.unique():
    est_temp = regress(df.loc[df.dept==dept])
    regression_tracker.update({dept:est_temp})
    print("------------ {} --------------".format(dept))
    print(est_temp.summary().tables[0])
# Out:
# ------------ Engineering --------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               comp_exp   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                     198.1
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):               0.00
# Time:                        20:08:27   Log-Likelihood:                 2217.9
# No. Observations:                2120   AIC:                            -4402.
# Df Residuals:                    2103   BIC:                            -4306.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
# ------------ Sales --------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               comp_exp   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                     6655.
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):               0.00
# Time:                        20:08:27   Log-Likelihood:                 5097.5
# No. Observations:                1491   AIC:                        -1.016e+04
# Df Residuals:                    1474   BIC:                        -1.007e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
# ------------ Product --------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               comp_exp   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     1765.
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):               0.00
# Time:                        20:08:27   Log-Likelihood:                 1973.7
# No. Observations:                 710   AIC:                            -3911.
# Df Residuals:                     692   BIC:                            -3829.
# Df Model:                          17
# Covariance Type:            nonrobust
# ==============================================================================
# ------------ Finance --------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               comp_exp   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     2404.
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):               0.00
# Time:                        20:08:28   Log-Likelihood:                 1186.0
# No. Observations:                 486   AIC:                            -2332.
# Df Residuals:                     466   BIC:                            -2248.
# Df Model:                          19
# Covariance Type:            nonrobust
# ==============================================================================
# ------------ IT --------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               comp_exp   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     555.0
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):          2.30e-119
# Time:                        20:08:28   Log-Likelihood:                 375.17
# No. Observations:                 159   AIC:                            -716.3
# Df Residuals:                     142   BIC:                            -664.2
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================

# %% [markdown]
# #### Finance

# %%
## Finance
coef_fin = format_coef(regression_tracker['Finance'])
coef_fin
# Out:
# 0                                         coef    std err          t   P>|t|  \
# 1                            const     10.9430      0.007   1495.766   0.000
# 2                          yrs_exp      0.0222      0.000     67.664   0.000
# 3      position_Finance Generalist     -0.0850      0.008    -11.147   0.000
# 4         position_Finance Manager      0.1104      0.003     41.097   0.000
# 5       position_Financial Analyst     -0.1458      0.007    -21.147   0.000
# 6   furthest_stage_New Application      0.0038      0.003      1.311   0.191
# 7        furthest_stage_Offer Sent      0.0046      0.006      0.829   0.407
# 8      furthest_stage_Phone Screen      0.0051      0.003      1.478   0.140
# 9                app_source_Agency      0.0014      0.004      0.334   0.739
# 10         app_source_Campus Event      0.0004      0.010      0.038   0.969
# 11     app_source_Campus Job Board     -0.0044      0.008     -0.552   0.581
# 12          app_source_Career Fair     -0.0034      0.005     -0.711   0.477
# 13    app_source_Internal Referral     -0.0063      0.006     -1.100   0.272
# 14           app_source_Outsourced     -0.0048      0.007     -0.680   0.497
# 15              app_source_Website      0.0009      0.004      0.203   0.839
# 16             industry_Government     -0.0018      0.003     -0.613   0.540
# 17                  industry_Other      0.0011      0.003      0.379   0.705
# 18             industry_Technology     -0.0009      0.003     -0.314   0.754
# 19          Highest Degree_Masters     -0.0025      0.002     -1.087   0.277
# 20              Highest Degree_PhD     -0.0006      0.004     -0.162   0.871
#
# 0      [0.025     0.975]    Exp. Coef.
# 1      10.929     10.957  56555.759173
# 2       0.022      0.023      0.022448
# 3      -0.100     -0.070     -0.081488
# 4       0.105      0.116      0.116725
# 5      -0.159     -0.132     -0.135669
# 6      -0.002      0.010      0.003807
# 7      -0.006      0.016      0.004611
# 8      -0.002      0.012      0.005113
# 9      -0.007      0.010      0.001401
# 10     -0.019      0.019      0.000400
# 11     -0.020      0.011     -0.004390
# 12     -0.013      0.006     -0.003394
# 13     -0.018      0.005     -0.006280
# 14     -0.019      0.009     -0.004788
# 15     -0.007      0.009      0.000900
# 16     -0.007      0.004     -0.001798
# 17     -0.005      0.007      0.001101
# 18     -0.007      0.005     -0.000900
# 19     -0.007      0.002     -0.002497
# 20     -0.008      0.007     -0.000600

# %% [markdown]
# #### IT

# %%
## IT
coef_it = format_coef(regression_tracker['IT'])
coef_it
# Out:
# 0                                         coef    std err          t   P>|t|  \
# 1                            const     10.8562      0.009   1156.190   0.000
# 2                          yrs_exp      0.0183      0.001     35.923   0.000
# 3    position_Sr. Business Analyst      0.1852      0.007     26.060   0.000
# 4   furthest_stage_New Application      0.0060      0.006      0.991   0.323
# 5        furthest_stage_Offer Sent      0.0198      0.009      2.082   0.039
# 6      furthest_stage_Phone Screen      0.0076      0.008      0.989   0.324
# 7                app_source_Agency     -0.0100      0.007     -1.405   0.162
# 8          app_source_Campus Event     -0.0272      0.010     -2.618   0.010
# 9      app_source_Campus Job Board     -0.0160      0.009     -1.851   0.066
# 10          app_source_Career Fair     -0.0242      0.008     -3.165   0.002
# 11    app_source_Internal Referral     -0.0088      0.012     -0.709   0.479
# 12              app_source_Website     -0.0071      0.007     -1.048   0.296
# 13             industry_Government     -0.0008      0.005     -0.138   0.890
# 14                  industry_Other      0.0025      0.006      0.461   0.645
# 15             industry_Technology  -4.286e-06      0.006     -0.001   0.999
# 16          Highest Degree_Masters     -0.0135      0.005     -2.832   0.005
# 17              Highest Degree_PhD     -0.0088      0.006     -1.523   0.130
#
# 0      [0.025     0.975]    Exp. Coef.
# 1      10.838     10.875  51853.655631
# 2       0.017      0.019      0.018468
# 3       0.171      0.199      0.203459
# 4      -0.006      0.018      0.006018
# 5       0.001      0.039      0.019997
# 6      -0.008      0.023      0.007629
# 7      -0.024      0.004     -0.009950
# 8      -0.048     -0.007     -0.026833
# 9      -0.033      0.001     -0.015873
# 10     -0.039     -0.009     -0.023910
# 11     -0.033      0.016     -0.008761
# 12     -0.020      0.006     -0.007075
# 13     -0.012      0.010     -0.000800
# 14     -0.008      0.013      0.002503
# 15     -0.011      0.011     -0.000004
# 16     -0.023     -0.004     -0.013409
# 17     -0.020      0.003     -0.008761

# %% [markdown]
# #### Product

# %%
coef_pr = format_coef(regression_tracker['Product'])
coef_pr
# Out:
# 0                                         coef    std err          t   P>|t|  \
# 1                            const     10.8855      0.004   3031.682   0.000
# 2                          yrs_exp      0.0360      0.000    119.500   0.000
# 3     position_Sr. Product Manager     -0.1841      0.004    -43.212   0.000
# 4             position_UX Designer     -0.1373      0.003    -50.310   0.000
# 5   furthest_stage_New Application      0.0020      0.002      1.174   0.241
# 6        furthest_stage_Offer Sent      0.0017      0.004      0.430   0.667
# 7      furthest_stage_Phone Screen     -0.0013      0.002     -0.672   0.502
# 8                app_source_Agency     -0.0080      0.003     -2.360   0.019
# 9          app_source_Campus Event      0.0043      0.003      1.492   0.136
# 10     app_source_Campus Job Board      0.0045      0.002      1.901   0.058
# 11          app_source_Career Fair      0.0034      0.003      1.264   0.207
# 12    app_source_Internal Referral      0.0170      0.006      3.083   0.002
# 13              app_source_Website      0.0043      0.003      1.671   0.095
# 14             industry_Government     -0.0007      0.002     -0.449   0.654
# 15                  industry_Other     -0.0012      0.002     -0.723   0.470
# 16             industry_Technology     -0.0004      0.002     -0.219   0.827
# 17          Highest Degree_Masters   8.805e-05      0.002      0.052   0.958
# 18              Highest Degree_PhD      0.0052      0.002      3.147   0.002
#
# 0      [0.025     0.975]    Exp. Coef.
# 1      10.878     10.893  53395.474384
# 2       0.035      0.037      0.036656
# 3      -0.192     -0.176     -0.168147
# 4      -0.143     -0.132     -0.128291
# 5      -0.001      0.005      0.002002
# 6      -0.006      0.009      0.001701
# 7      -0.005      0.003     -0.001299
# 8      -0.015     -0.001     -0.007968
# 9      -0.001      0.010      0.004309
# 10     -0.000      0.009      0.004510
# 11     -0.002      0.009      0.003406
# 12      0.006      0.028      0.017145
# 13     -0.001      0.009      0.004309
# 14     -0.004      0.003     -0.000700
# 15     -0.004      0.002     -0.001199
# 16     -0.004      0.003     -0.000400
# 17     -0.003      0.003      0.000088
# 18      0.002      0.008      0.005214

# %% [markdown]
# #### Sales

# %%
coef_s = format_coef(regression_tracker['Sales'])
coef_s
# Out:
# 0                                                  coef    std err          t  \
# 1                                     const     11.0678      0.001   8106.951
# 2                                   yrs_exp      0.0275    8.5e-05    323.937
# 3   position_Associate Relationship Manager     -0.0740      0.001    -79.782
# 4            furthest_stage_New Application     -0.0005      0.001     -0.825
# 5                 furthest_stage_Offer Sent     -0.0013      0.002     -0.750
# 6               furthest_stage_Phone Screen     -0.0008      0.001     -0.978
# 7                         app_source_Agency      0.0075      0.002      4.829
# 8                   app_source_Campus Event     -0.0025      0.001     -2.919
# 9               app_source_Campus Job Board     -0.0026      0.001     -3.460
# 10                   app_source_Career Fair     -0.0016      0.001     -1.748
# 11             app_source_Internal Referral      0.0084      0.005      1.777
# 12                       app_source_Website     -0.0001      0.001     -0.150
# 13                      industry_Government      0.0007      0.001      1.187
# 14                           industry_Other     -0.0002      0.001     -0.296
# 15                      industry_Technology     -0.0001      0.001     -0.249
# 16                   Highest Degree_Masters     -0.0002      0.000     -0.541
# 17                       Highest Degree_PhD      0.0019      0.001      1.858
#
# 0    P>|t|     [0.025     0.975]    Exp. Coef.
# 1    0.000     11.065     11.071  64073.388008
# 2    0.000      0.027      0.028      0.027882
# 3    0.000     -0.076     -0.072     -0.071328
# 4    0.410     -0.002      0.001     -0.000500
# 5    0.453     -0.005      0.002     -0.001299
# 6    0.328     -0.002      0.001     -0.000800
# 7    0.000      0.004      0.011      0.007528
# 8    0.004     -0.004     -0.001     -0.002497
# 9    0.001     -0.004     -0.001     -0.002597
# 10   0.081     -0.003      0.000     -0.001599
# 11   0.076     -0.001      0.018      0.008435
# 12   0.881     -0.002      0.002     -0.000100
# 13   0.235     -0.000      0.002      0.000700
# 14   0.767     -0.001      0.001     -0.000200
# 15   0.803     -0.001      0.001     -0.000100
# 16   0.589     -0.001      0.001     -0.000200
# 17   0.063     -0.000      0.004      0.001902

# %% [markdown]
# #### Engineering

# %%
coef_e = format_coef(regression_tracker['Engineering'])
coef_e
# Out:
# 0                                         coef    std err          t   P>|t|  \
# 1                            const     10.0714      0.024    418.768   0.000
# 2                          yrs_exp      0.0357      0.001     42.900   0.000
# 3   position_Sr. Software Engineer      0.5540      0.025     22.329   0.000
# 4   furthest_stage_New Application      0.0012      0.006      0.185   0.854
# 5        furthest_stage_Offer Sent     -0.0077      0.013     -0.577   0.564
# 6      furthest_stage_Phone Screen     -0.0014      0.007     -0.197   0.844
# 7                app_source_Agency      0.0661      0.029      2.242   0.025
# 8          app_source_Campus Event      0.0070      0.008      0.879   0.380
# 9      app_source_Campus Job Board      0.0056      0.007      0.851   0.395
# 10          app_source_Career Fair      0.0073      0.006      1.130   0.259
# 11    app_source_Internal Referral     -0.0567      0.055     -1.030   0.303
# 12              app_source_Website      0.0250      0.008      2.971   0.003
# 13             industry_Government     -0.0007      0.005     -0.132   0.895
# 14                  industry_Other      0.0048      0.005      0.914   0.361
# 15             industry_Technology     -0.0073      0.005     -1.417   0.157
# 16          Highest Degree_Masters      0.0069      0.006      1.170   0.242
# 17              Highest Degree_PhD      0.0050      0.006      0.853   0.394
#
# 0      [0.025     0.975]    Exp. Coef.
# 1      10.024     10.119  23655.660922
# 2       0.034      0.037      0.036345
# 3       0.505      0.603      0.740200
# 4      -0.011      0.014      0.001201
# 5      -0.034      0.018     -0.007670
# 6      -0.016      0.013     -0.001399
# 7       0.008      0.124      0.068334
# 8      -0.009      0.023      0.007025
# 9      -0.007      0.019      0.005616
# 10     -0.005      0.020      0.007327
# 11     -0.165      0.051     -0.055123
# 12      0.009      0.042      0.025315
# 13     -0.011      0.010     -0.000700
# 14     -0.005      0.015      0.004812
# 15     -0.018      0.003     -0.007273
# 16     -0.005      0.018      0.006924
# 17     -0.007      0.017      0.005013

# %% [markdown]
# ## Statistical Tests

# %%
df['PhD/xPhD'] = np.where(df['Highest Degree']=='PhD',"PhD", "Not PhD")

# %%
def expectation_differences(df, var, alpha=0.05):
    if var is None:
        A = df[(df['PhD/xPhD']=='PhD')]['comp_exp'].values.tolist()
        B = df[(df['PhD/xPhD']!='PhD')]['comp_exp'].values.tolist()
        t_check=stats.ttest_ind(A,B)
        sig = "Yes" if t_check[1]<alpha else "No"
        print("PhD Expectations: {:.0f}| XPhD Expectations: {:.0f} | Diff: {:.1%} | Sig?: {}".format(np.mean(A), np.mean(B), np.mean(A)/np.mean(B)-1, sig))
    else:
        for v in df[var].unique():
            A = df[(df['PhD/xPhD']=='PhD')&(df[var]==v)]['comp_exp'].values.tolist()
            B = df[(df['PhD/xPhD']!='PhD')&(df[var]==v)]['comp_exp'].values.tolist()
            t_check=stats.ttest_ind(A,B)
            sig = "Yes" if t_check[1]<alpha else "No"
            print(var, ": {} | PhD Expectations: {:.0f}| XPhD Expectations: {:.0f} | Diff: {:.1%} | Sig?: {}".format(v,np.mean(A), np.mean(B), np.mean(A)/np.mean(B)-1, sig))

# %%
expectation_differences(df, var=None)
# Out:
# PhD Expectations: 72440| XPhD Expectations: 71821 | Diff: 0.9% | Sig?: No

# %%
expectation_differences(df, var='dept')
# Out:
# dept : Engineering | PhD Expectations: 72213| XPhD Expectations: 63664 | Diff: 13.4% | Sig?: Yes
# dept : Sales | PhD Expectations: 78435| XPhD Expectations: 79405 | Diff: -1.2% | Sig?: No
# dept : Product | PhD Expectations: 70934| XPhD Expectations: 69797 | Diff: 1.6% | Sig?: No
# dept : Finance | PhD Expectations: 77026| XPhD Expectations: 76781 | Diff: 0.3% | Sig?: No
# dept : IT | PhD Expectations: 64906| XPhD Expectations: 75406 | Diff: -13.9% | Sig?: Yes

# %%
expectation_differences(df, var='industry')
# Out:
# industry : Government | PhD Expectations: 72520| XPhD Expectations: 71872 | Diff: 0.9% | Sig?: No
# industry : Other | PhD Expectations: 73821| XPhD Expectations: 71844 | Diff: 2.8% | Sig?: No
# industry : Finance | PhD Expectations: 71740| XPhD Expectations: 71766 | Diff: -0.0% | Sig?: No
# industry : Technology | PhD Expectations: 71679| XPhD Expectations: 71804 | Diff: -0.2% | Sig?: No

# %%
expectation_differences(df, var='position')
# Out:
# position : Associate Software Developer | PhD Expectations: 70753| XPhD Expectations: 63538 | Diff: 11.4% | Sig?: Yes
# position : Associate Relationship Manager | PhD Expectations: 79282| XPhD Expectations: 79337 | Diff: -0.1% | Sig?: No
# position : Associate Product Manager | PhD Expectations: 70463| XPhD Expectations: 67841 | Diff: 3.9% | Sig?: Yes
# position : Finance Manager | PhD Expectations: 91082| XPhD Expectations: 89238 | Diff: 2.1% | Sig?: No
# position : Finance Generalist | PhD Expectations: 59760| XPhD Expectations: 57680 | Diff: 3.6% | Sig?: No
# position : Business Operations Manager | PhD Expectations: 84108| XPhD Expectations: 83996 | Diff: 0.1% | Sig?: No
# position : Sr. Business Analyst | PhD Expectations: 82733| XPhD Expectations: 82303 | Diff: 0.5% | Sig?: No
# position : Sr. Product Manager | PhD Expectations: 87240| XPhD Expectations: 85291 | Diff: 2.3% | Sig?: No
# position : IT Analyst | PhD Expectations: 58488| XPhD Expectations: 59000 | Diff: -0.9% | Sig?: No
# position : Sr. Software Engineer | PhD Expectations: 120539| XPhD Expectations: 78146 | Diff: 54.2% | Sig?: No
# position : UX Designer | PhD Expectations: 66925| XPhD Expectations: 65746 | Diff: 1.8% | Sig?: No
# position : Financial Analyst | PhD Expectations: 54782| XPhD Expectations: 56080 | Diff: -2.3% | Sig?: No
# position : Account Executive | PhD Expectations: 76883| XPhD Expectations: 80135 | Diff: -4.1% | Sig?: Yes

# %%
agg = df.groupby(['PhD/xPhD','position']).agg({'cand_id':'count','comp_exp':'mean'}).reset_index().merge(df['PhD/xPhD'].value_counts().reset_index(), left_on=['PhD/xPhD'], right_on=['index'])
agg['Ratio'] = agg['cand_id']/agg['PhD/xPhD_y']
agg
# Out:
#    PhD/xPhD_x                        position  cand_id       comp_exp  \
# 0     Not PhD               Account Executive      121   80134.710744
# 1     Not PhD       Associate Product Manager      443   67840.632054
# 2     Not PhD  Associate Relationship Manager     1302   79336.789555
# 3     Not PhD    Associate Software Developer     1493   63538.245144
# 4     Not PhD     Business Operations Manager      147   83995.918367
# 5     Not PhD              Finance Generalist      123   57680.487805
# 6     Not PhD                 Finance Manager      145   89237.931034
# 7     Not PhD               Financial Analyst       25   56080.000000
# 8     Not PhD                      IT Analyst       37   59000.000000
# 9     Not PhD            Sr. Business Analyst       88   82303.409091
# 10    Not PhD             Sr. Product Manager       69   85291.304348
# 11    Not PhD           Sr. Software Engineer       13   78146.153846
# 12    Not PhD                     UX Designer       50   65746.000000
# 13        PhD               Account Executive       24   76883.333333
# 14        PhD       Associate Product Manager      139   70462.589928
# 15        PhD  Associate Relationship Manager       44   79281.818182
# 16        PhD    Associate Software Developer      596   70753.355705
# 17        PhD     Business Operations Manager       13   84107.692308
# 18        PhD              Finance Generalist        5   59760.000000
# 19        PhD                 Finance Manager       17   91082.352941
# 20        PhD               Financial Analyst       11   54781.818182
# 21        PhD                      IT Analyst       25   58488.000000
# 22        PhD            Sr. Business Analyst        9   82733.333333
# 23        PhD             Sr. Product Manager        5   87240.000000
# 24        PhD           Sr. Software Engineer       18  120538.888889
# 25        PhD                     UX Designer        4   66925.000000
#
#       index  PhD/xPhD_y     Ratio
# 0   Not PhD        4056  0.029832
# 1   Not PhD        4056  0.109221
# 2   Not PhD        4056  0.321006
# 3   Not PhD        4056  0.368097
# 4   Not PhD        4056  0.036243
# 5   Not PhD        4056  0.030325
# 6   Not PhD        4056  0.035750
# 7   Not PhD        4056  0.006164
# 8   Not PhD        4056  0.009122
# 9   Not PhD        4056  0.021696
# 10  Not PhD        4056  0.017012
# 11  Not PhD        4056  0.003205
# 12  Not PhD        4056  0.012327
# 13      PhD         910  0.026374
# 14      PhD         910  0.152747
# 15      PhD         910  0.048352
# 16      PhD         910  0.654945
# 17      PhD         910  0.014286
# 18      PhD         910  0.005495
# 19      PhD         910  0.018681
# 20      PhD         910  0.012088
# 21      PhD         910  0.027473
# 22      PhD         910  0.009890
# 23      PhD         910  0.005495
# 24      PhD         910  0.019780
# 25      PhD         910  0.004396
